# %% [markdown]
# <table align="left"><tr><td>
# <a href="https://colab.research.google.com/github/rickiepark/nlp-with-transformers/blob/main/08_model-compression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="코랩에서 실행하기"/></a>
# </td></tr></table>

# %%
# 코랩이나 캐글을 사용한다면 이 셀의 주석을 제거하고 실행하세요.
#!git clone https://github.com/rickiepark/nlp-with-transformers.git
#%cd nlp-with-transformers
#from install import *
#install_requirements(chapter=8)

# %% [markdown]
# # 효율적인 트랜스포머 구축

# %% [markdown]
# <img alt="Scaling BERT at Roblox" caption="How Roblox scaled BERT with knowledge distillation, dynamic padding, and weight quantization (photo courtesy of Roblox employees Quoc N. Le and Kip Kaehler)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_roblox.png?raw=1" id="roblox"/>

# %% [markdown]
# ## 의도 탐지 예제

# %% [markdown]
# <img alt="Out of Scope Query" width="400" caption="Three exchanges between a human (right) and a text-based assistant (left) for personal finance (courtesy of Stefan Larson et al.)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_oos.png?raw=1" id="oos"/>

# %%
from transformers import pipeline

bert_ckpt = "transformersbook/bert-base-uncased-finetuned-clinc"
pipe = pipeline("text-classification", model=bert_ckpt)
# Out:
# 2025-03-25 07:13:11.220014: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-25 07:13:11.220078: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-25 07:13:11.220164: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-25 07:13:11.239541: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-25 07:13:12.435321: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/yunheur/.pyenv/versions/3.10.16/envs/book-nlp-with-transormers/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /home/yunheur/.pyenv/versions/3.10.16/envs/book-nlp-with-transormers/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
query = """Hey, I'd like to rent a vehicle from Nov 1st to Nov 15th in
Paris and I need a 15 passenger van"""
pipe(query)
# Out:
# [{'label': 'car_rental', 'score': 0.5490033030509949}]

# %% [markdown]
# ## 벤치마크 클래스 만들기

# %%
class PerformanceBenchmark:
    def __init__(self, pipeline, dataset, optim_type="BERT baseline"):
        self.pipeline = pipeline
        self.dataset = dataset
        self.optim_type = optim_type

    def compute_accuracy(self):
        # 나중에 정의합니다
        pass

    def compute_size(self):
        # 나중에 정의합니다
        pass

    def time_pipeline(self):
        # 나중에 정의합니다
        pass

    def run_benchmark(self):
        metrics = {}
        metrics[self.optim_type] = self.compute_size()
        metrics[self.optim_type].update(self.time_pipeline())
        metrics[self.optim_type].update(self.compute_accuracy())
        return metrics

# %%
from datasets import load_dataset

clinc = load_dataset("clinc_oos", "plus")
# Out:
# Downloading readme:   0%|          | 0.00/24.0k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/312k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/136k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/15250 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3100 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5500 [00:00<?, ? examples/s]

# %%
sample = clinc["test"][42]
sample
# Out:
# {'text': 'transfer $100 from my checking to saving account', 'intent': 133}

# %%
intents = clinc["test"].features["intent"]
intents.int2str(sample["intent"])
# Out:
# 'transfer'

# %%
#!pip install evaluate

# %%
import evaluate

accuracy_score = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
def compute_accuracy(self):
    """PerformanceBenchmark.compute_accuracy() 메서드를 오버라이드합니다"""
    preds, labels = [], []
    for example in self.dataset:
        pred = self.pipeline(example["text"])[0]["label"]
        label = example["intent"]
#           1.1058e-01, -9.1731e-04,  8.6605e-02, -1.7707e-02,  1.2616e-02,
#           1.8871e-01, -1.0594e-01, -3.7989e-03, -6.6359e-02, -5.9799e-02,
#           4.3201e-03, -2.3140e-02,  4.8008e-03,  1.4294e-02, -9.5453e-03,
#           5.8454e-03,  8.6512e-03,  2.1151e-02,  1.7098e-02, -1.4637e-03,
#           1.3778e-02, -1.2843e-02,  2.3742e-02, -1.3895e-02,  1.1327e-03,
#          -7.0846e-03, -7.6255e-03, -8.2264e-03, -1.5513e-02,  4.2724e-03,
#          -1.7624e-02, -3.0984e-03, -1.4400e-02,  2.3883e-02,  1.1556e-01,
#           4.4036e-02,  3.2821e-02,  8.6612e-04,  1.2383e-02, -6.6263e-03,
#          -2.7201e-03,  4.8125e-03, -2.8362e-03,  3.9830e-02,  5.2414e-02,
#          -4.6269e-03, -1.5858e-02,  2.1845e-02, -1.3767e-02, -1.0629e-02,
#           1.0347e-02, -3.4209e-02,  1.6939e-02,  1.8120e-02,  3.0650e-03,
#          -2.5109e-03,  1.3500e-02, -3.6440e-02, -9.2135e-03,  9.2194e-03,
#          -3.6276e-02, -1.1555e-02, -1.9569e-02, -1.5417e-02, -2.0485e-02,
#           2.9770e-03, -6.8246e-03, -6.5039e-03, -1.2597e-02, -1.1409e-02,
#           1.7139e-02,  4.6424e-03, -5.1774e-02, -1.1679e-02,  5.2761e-03,
#          -1.3664e-02, -1.4001e-02,  2.0379e-03,  1.2753e-02, -8.1607e-03,
#          -1.0849e-02, -1.0683e-03, -2.4489e-03,  2.0192e-02,  1.5756e-02,
#          -6.4964e-03, -4.5603e-02, -2.5999e-02, -1.4307e-02, -7.4639e-03,
#           9.9480e-03,  1.6763e-02,  2.1737e-02,  4.8181e-02,  1.7739e-02,
#           1.1469e-02, -4.2359e-03, -1.6419e-02, -1.7318e-02,  1.1498e-03,
#           2.4485e-02, -3.0614e-03,  1.9017e-02, -1.6453e-02, -1.3444e-02,
#           2.6748e-02, -6.4994e-03,  5.1485e-03,  1.4132e-02, -1.1573e-02,
#           1.2583e-02, -1.1401e-02, -2.0003e-02, -3.8115e-03,  7.3728e-03,
#           1.5500e-02,  2.0623e-02,  3.1582e-03, -1.2794e-02,  4.5499e-03,
#          -3.3994e-04, -2.3003e-02,  1.2225e-02, -2.7949e-02, -9.6121e-03,
#          -3.5844e-02, -4.2373e-03,  5.3473e-03,  1.4432e-02, -1.2745e-02,
#           7.1483e-03,  2.9170e-03,  6.2454e-03,  6.8991e-03,  1.5852e-02,
#           2.1877e-02, -1.7211e-02, -2.6093e-02]))

# %%
import torch
from pathlib import Path

def compute_size(self):
    """PerformanceBenchmark.compute_size() 메서드를 오버라이드합니다"""
    state_dict = self.pipeline.model.state_dict()
    tmp_path = Path("model.pt")
    torch.save(state_dict, tmp_path)
    # 메가바이트 단위로 크기를 계산합니다
    size_mb = Path(tmp_path).stat().st_size / (1024 * 1024)
    # 임시 파일을 삭제합니다
    tmp_path.unlink()
    print(f"모델 크기 (MB) - {size_mb:.2f}")
    return {"size_mb": size_mb}

PerformanceBenchmark.compute_size = compute_size

# %%
from time import perf_counter

for _ in range(3):
    start_time = perf_counter()
    _ = pipe(query)
    latency = perf_counter() - start_time
    print(f"레이턴시 (ms) - {1000 * latency:.3f}")
# Out:
# 레이턴시 (ms) - 53.538
# 레이턴시 (ms) - 46.334
# 레이턴시 (ms) - 44.938

# %%
import numpy as np

def time_pipeline(self, query="What is the pin number for my account?"):
    """PerformanceBenchmark.time_pipeline() 메서드를 오버라이드합니다d"""
    latencies = []
    # 워밍업
    for _ in range(10):
        _ = self.pipeline(query)
    # 실행 측정
    for _ in range(100):
        start_time = perf_counter()
        _ = self.pipeline(query)
        latency = perf_counter() - start_time
        latencies.append(latency)
    # 통게 계산
    time_avg_ms = 1000 * np.mean(latencies)
    time_std_ms = 1000 * np.std(latencies)
    print(f"평균 레이턴시 (ms) - {time_avg_ms:.2f} +\- {time_std_ms:.2f}")
    return {"time_avg_ms": time_avg_ms, "time_std_ms": time_std_ms}

PerformanceBenchmark.time_pipeline = time_pipeline

# %%
pb = PerformanceBenchmark(pipe, clinc["test"])
perf_metrics = pb.run_benchmark()
# Out:
# 모델 크기 (MB) - 418.15
# 평균 레이턴시 (ms) - 40.13 +\- 2.75
# 테스트 세트 정확도 - 0.867

# %% [markdown]
# ## 지식 정제로 모델 크기 줄이기

# %% [markdown]
# ### 미세 튜닝을 위한 지식 정제

# %% [markdown]
# <img alt="Soft Probabilities" caption="Comparison of a hard label that is one-hot encoded (left), softmax probabilities (middle), and softened class probabilities (right)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_soft-probs.png?raw=1" id="soft-probs"/>

# %% [markdown]
# <img alt="Knowledge distillation" caption="The knowledge distillation process" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_kd.png?raw=1" id="kd"/>

# %% [markdown]
# ### 사전 훈련을 위한 지식 정제

# %% [markdown]
# ### 지식 정제 트레이너 만들기

# %%
from transformers import TrainingArguments

class DistillationTrainingArguments(TrainingArguments):
    def __init__(self, *args, alpha=0.5, temperature=2.0, **kwargs):
        super().__init__(*args, **kwargs)
        self.alpha = alpha
        self.temperature = temperature

# %%
import torch.nn as nn
import torch.nn.functional as F
from transformers import Trainer

class DistillationTrainer(Trainer):
    def __init__(self, *args, teacher_model=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.teacher_model = teacher_model

    def compute_loss(self, model, inputs, return_outputs=False):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        inputs = inputs.to(device)
        outputs_stu = model(**inputs)
        # 스튜던트의 크로스 엔트로피 손실과 로짓을 추출합니다
        loss_ce = outputs_stu.loss
        logits_stu = outputs_stu.logits
        # 티처의 로짓을 추출합니다
        with torch.no_grad():
            outputs_tea = self.teacher_model(**inputs)
            logits_tea = outputs_tea.logits
        # 확률을 부드럽게하고 정제 손실을 계산합니다
        loss_fct = nn.KLDivLoss(reduction="batchmean")
        loss_kd = self.args.temperature ** 2 * loss_fct(
            F.log_softmax(logits_stu / self.args.temperature, dim=-1),
            F.softmax(logits_tea / self.args.temperature, dim=-1))
        # 가중 평균된 스튜던트 손실을 반환합니다
        loss = self.args.alpha * loss_ce + (1. - self.args.alpha) * loss_kd
        return (loss, outputs_stu) if return_outputs else loss

# %% [markdown]
# ### 좋은 스튜던트 초기화 선택하기

# %%
from transformers import AutoTokenizer

student_ckpt = "distilbert-base-uncased"
student_tokenizer = AutoTokenizer.from_pretrained(student_ckpt)

def tokenize_text(batch):
    return student_tokenizer(batch["text"], truncation=True)

clinc_enc = clinc.map(tokenize_text, batched=True, remove_columns=["text"])
clinc_enc = clinc_enc.rename_column("intent", "labels")
# Out:
# Map:   0%|          | 0/15250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5500 [00:00<?, ? examples/s]

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
def compute_metrics(pred):
    predictions, labels = pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy_score.compute(predictions=predictions, references=labels)

# %%
batch_size = 48

finetuned_ckpt = "distilbert-base-uncased-finetuned-clinc"
student_training_args = DistillationTrainingArguments(
    output_dir=finetuned_ckpt, evaluation_strategy = "epoch",
    num_train_epochs=5, learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size, alpha=1, weight_decay=0.01,
    push_to_hub=True)

# %%
student_training_args.logging_steps = len(clinc_enc['train']) // batch_size
student_training_args.disable_tqdm = False
student_training_args.save_steps = 1e9
# 트랜스포머 4.23.0 버전부터 로깅 수준을 문자열로 지정해야 합니다.
# student_training_args.log_level = 40
student_training_args.log_level = 'error'

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
id2label = pipe.model.config.id2label
label2id = pipe.model.config.label2id

# %%
from transformers import AutoConfig

num_labels = intents.num_classes
student_config = (AutoConfig
                  .from_pretrained(student_ckpt, num_labels=num_labels,
                                   id2label=id2label, label2id=label2id))

# %%
import torch
from transformers import AutoModelForSequenceClassification

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def student_init():
    return (AutoModelForSequenceClassification
            .from_pretrained(student_ckpt, config=student_config).to(device))

# %%
teacher_ckpt = "transformersbook/bert-base-uncased-finetuned-clinc"
teacher_model = (AutoModelForSequenceClassification
                 .from_pretrained(teacher_ckpt, num_labels=num_labels)
                 .to(device))

# %%
distilbert_trainer = DistillationTrainer(model_init=student_init,
    teacher_model=teacher_model, args=student_training_args,
    train_dataset=clinc_enc['train'], eval_dataset=clinc_enc['validation'],
    compute_metrics=compute_metrics, tokenizer=student_tokenizer)

distilbert_trainer.train()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: yunheur (yunheur-none). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_071743-or343xyu</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/or343xyu' target="_blank">grateful-fire-16</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/or343xyu' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/or343xyu</a>
#     <div>
#
#       <progress value='1590' max='1590' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1590/1590 01:42, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.295700</td>
#       <td>3.277222</td>
#       <td>0.722903</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.609700</td>
#       <td>1.859495</td>
#       <td>0.843226</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.534000</td>
#       <td>1.143629</td>
#       <td>0.898387</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.003100</td>
#       <td>0.847327</td>
#       <td>0.913226</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.784200</td>
#       <td>0.764882</td>
#       <td>0.920323</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1590, training_loss=2.0412518259864183, metrics={'train_runtime': 105.3247, 'train_samples_per_second': 723.952, 'train_steps_per_second': 15.096, 'total_flos': 413013830824140.0, 'train_loss': 2.0412518259864183, 'epoch': 5.0})

# %%
distilbert_trainer.push_to_hub("Training completed!")
# Out:
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# 'https://huggingface.co/yunheur/distilbert-base-uncased-finetuned-clinc/tree/main/'

# %%
# `haesun`를 자신의 허브 사용자 이름으로 바꾸세요.
finetuned_ckpt = "haesun/distilbert-base-uncased-finetuned-clinc"
pipe = pipeline("text-classification", model=finetuned_ckpt)
# Out:
# Downloading config.json:   0%|          | 0.00/8.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
optim_type = "DistilBERT"
pb = PerformanceBenchmark(pipe, clinc["test"], optim_type=optim_type)
perf_metrics.update(pb.run_benchmark())
# Out:
# 모델 크기 (MB) - 255.88
# 평균 레이턴시 (ms) - 21.80 +\- 1.63
# 테스트 세트 정확도 - 0.856

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_metrics(perf_metrics, current_optim_type):
    df = pd.DataFrame.from_dict(perf_metrics, orient='index')

    for idx in df.index:
        df_opt = df.loc[idx]
        # 현재 최적화 방법을 점선으로 그립니다
        if idx == current_optim_type:
            plt.scatter(df_opt["time_avg_ms"], df_opt["accuracy"] * 100,
                        alpha=0.5, s=df_opt["size_mb"], label=idx,
                        marker='$\u25CC$')
        else:
            plt.scatter(df_opt["time_avg_ms"], df_opt["accuracy"] * 100,
                        s=df_opt["size_mb"], label=idx, alpha=0.5)

    legend = plt.legend(bbox_to_anchor=(1,1))
    for handle in legend.legend_handles:
        handle.set_sizes([20])

    plt.ylim(80,90)
    # 가장 느린 모델을 사용해 x 축 범위를 정합니다
    xlim = int(perf_metrics["BERT baseline"]["time_avg_ms"] + 3)
    plt.xlim(1, xlim)
    plt.ylabel("Accuracy (%)")
    plt.xlabel("Average latency (ms)")
    plt.show()

plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ### 옵투나로 좋은 하이퍼파라미터 찾기

# %%
# 두 변수를 가진 로젠브록 함수 그래프
import matplotlib.pyplot as plt
import numpy as np

def f(x, y):
    return (1-x)**2+100*(y-x**2)**2

X, Y = np.meshgrid(np.linspace(-2, 2, 250), np.linspace(-1, 3, 250))
Z = f(X,Y)
_, ax = plt.subplots()
ax.plot([1], [1], 'x', mew=3, markersize=10, color="red")
ax.contourf(X, Y, Z, np.logspace(-1, 3, 30), cmap='viridis', extend="both")
ax.set_xlim(-1.3, 1.3)
ax.set_ylim(-0.9, 1.7)
plt.show()

# %%
def objective(trial):
    x = trial.suggest_float("x", -2, 2)
    y = trial.suggest_float("y", -2, 2)
    return (1 - x) ** 2 + 100 * (y - x ** 2) ** 2

# %%
import optuna

study = optuna.create_study()
study.optimize(objective, n_trials=1000)
# Out:
# [I 2025-03-25 07:38:25,394] A new study created in memory with name: no-name-3bd8ba36-0c0b-4816-b5ef-b629b1a95231
# [I 2025-03-25 07:38:25,398] Trial 0 finished with value: 451.3593349708542 and parameters: {'x': 1.3551718829293278, 'y': -0.28773417440711535}. Best is trial 0 with value: 451.3593349708542.
# [I 2025-03-25 07:38:25,399] Trial 1 finished with value: 78.87380701979555 and parameters: {'x': -1.5748488179996998, 'y': 1.630184326272544}. Best is trial 1 with value: 78.87380701979555.
# [I 2025-03-25 07:38:25,401] Trial 2 finished with value: 1.8909800503768772 and parameters: {'x': 1.3799093179044433, 'y': 1.7719888781639295}. Best is trial 2 with value: 1.8909800503768772.
# [I 2025-03-25 07:38:25,403] Trial 3 finished with value: 311.52285474152086 and parameters: {'x': 0.35367150627750465, 'y': 1.8889007420578738}. Best is trial 2 with value: 1.8909800503768772.
# [I 2025-03-25 07:38:25,405] Trial 4 finished with value: 19.319982279902234 and parameters: {'x': 1.2316785966906982, 'y': 1.0780981464982564}. Best is trial 2 with value: 1.8909800503768772.
. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,102] Trial 993 finished with value: 0.8901157556575929 and parameters: {'x': 1.0739429504421982, 'y': 1.059297722237541}. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,121] Trial 994 finished with value: 73.96032551909079 and parameters: {'x': -0.3031074540416274, 'y': 0.9419461049559134}. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,139] Trial 995 finished with value: 0.014606700470891862 and parameters: {'x': 0.9281636967296567, 'y': 0.851768667918578}. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,159] Trial 996 finished with value: 0.25379922398490373 and parameters: {'x': 0.8414209624845914, 'y': 0.7558067969879043}. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,180] Trial 997 finished with value: 0.31269542319542454 and parameters: {'x': 0.8167624522369561, 'y': 0.7199326574989773}. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,209] Trial 998 finished with value: 0.05138129753296614 and parameters: {'x': 0.8881499244172526, 'y': 0.7690945944617561}. Best is trial 459 with value: 0.00011251209064115735.
# [I 2025-03-25 07:38:40,232] Trial 999 finished with value: 0.4280749469426227 and parameters: {'x': 0.9403958054226648, 'y': 0.8191888960259568}. Best is trial 459 with value: 0.00011251209064115735.

# %%
study.best_params
# Out:
# {'x': 0.989671367840762, 'y': 0.9796909002437729}

# %%
def hp_space(trial):
    return {"num_train_epochs": trial.suggest_int("num_train_epochs", 5, 10),
        "alpha": trial.suggest_float("alpha", 0, 1),
        "temperature": trial.suggest_int("temperature", 2, 20)}

# %%
best_run = distilbert_trainer.hyperparameter_search(
    n_trials=20, direction="maximize", hp_space=hp_space)
# Out:
# [I 2025-03-25 07:38:40,337] A new study created in memory with name: no-name-53ad1d61-b82d-41d9-84b5-d04e241ecc48
# VBox(children=(Label(value='0.213 MB of 0.213 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▅▇██</td></tr><tr><td>eval/loss</td><td>█▄▂▁▁</td></tr><tr><td>eval/runtime</td><td>▇▂▁▂█</td></tr><tr><td>eval/samples_per_second</td><td>▂▆█▇▁</td></tr><tr><td>eval/steps_per_second</td><td>▂▆█▇▁</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▄▅▆▆███</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▄▅▆▆███</td></tr><tr><td>train/learning_rate</td><td>█▆▅▃▁</td></tr><tr><td>train/loss</td><td>█▅▂▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.92032</td></tr><tr><td>eval/loss</td><td>0.76488</td></tr><tr><td>eval/runtime</td><td>2.872</td></tr><tr><td>eval/samples_per_second</td><td>1079.401</td></tr><tr><td>eval/steps_per_second</td><td>22.633</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>1590</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.7842</td></tr><tr><td>train/total_flos</td><td>413013830824140.0</td></tr><tr><td>train/train_loss</td><td>2.04125</td></tr><tr><td>train/train_runtime</td><td>105.3247</td></tr><tr><td>train/train_samples_per_second</td><td>723.952</td></tr><tr><td>train/train_steps_per_second</td><td>15.096</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grateful-fire-16</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/or343xyu' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/or343xyu</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_071743-or343xyu/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_073845-5nbdkkkj</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/5nbdkkkj' target="_blank">celestial-morning-17</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/5nbdkkkj' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/5nbdkkkj</a>
#     <div>
#
#       <progress value='2862' max='2862' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2862/2862 03:09, Epoch 9/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.396900</td>
#       <td>0.202211</td>
#       <td>0.593226</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.168700</td>
#       <td>0.097938</td>
#       <td>0.832258</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.103600</td>
#       <td>0.064488</td>
#       <td>0.890323</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.077600</td>
#       <td>0.048596</td>
#       <td>0.902903</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.063800</td>
#       <td>0.040760</td>
#       <td>0.916774</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.055900</td>
#       <td>0.035885</td>
#       <td>0.913548</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.051000</td>
#       <td>0.032883</td>
#       <td>0.918065</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.047800</td>
#       <td>0.031353</td>
#       <td>0.919032</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.046500</td>
#       <td>0.030810</td>
#       <td>0.920323</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 07:41:57,034] Trial 0 finished with value: 0.9203225806451613 and parameters: {'num_train_epochs': 9, 'alpha': 0.906483528403429, 'temperature': 12}. Best is trial 0 with value: 0.9203225806451613.
# VBox(children=(Label(value='0.024 MB of 0.024 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇██████</td></tr><tr><td>eval/loss</td><td>█▄▂▂▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▇▂█▂▃▇▁▄▃</td></tr><tr><td>eval/samples_per_second</td><td>▂▇▁▇▆▂█▄▆</td></tr><tr><td>eval/steps_per_second</td><td>▂▇▁▇▆▂█▄▆</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▃▃▄▄▄▅▅▅▆▆▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▃▃▄▄▄▅▅▅▆▆▇▇███</td></tr><tr><td>train/learning_rate</td><td>█▇▆▅▅▄▃▂▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.92032</td></tr><tr><td>eval/loss</td><td>0.03081</td></tr><tr><td>eval/runtime</td><td>2.2029</td></tr><tr><td>eval/samples_per_second</td><td>1407.256</td></tr><tr><td>eval/steps_per_second</td><td>29.507</td></tr><tr><td>train/epoch</td><td>9</td></tr><tr><td>train/global_step</td><td>2862</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0465</td></tr><tr><td>train/total_flos</td><td>743498049913920.0</td></tr><tr><td>train/train_loss</td><td>0.11219</td></tr><tr><td>train/train_runtime</td><td>195.8709</td></tr><tr><td>train/train_samples_per_second</td><td>700.717</td></tr><tr><td>train/train_steps_per_second</td><td>14.612</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">celestial-morning-17</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/5nbdkkkj' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/5nbdkkkj</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_073845-5nbdkkkj/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_074201-gl0b8qv6</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/gl0b8qv6' target="_blank">logical-brook-18</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/gl0b8qv6' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/gl0b8qv6</a>
#     <div>
#
#       <progress value='3180' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3180/3180 03:31, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.409300</td>
#       <td>0.207782</td>
#       <td>0.602903</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.172500</td>
#       <td>0.098797</td>
#       <td>0.837097</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.104300</td>
#       <td>0.063775</td>
#       <td>0.894194</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.077100</td>
#       <td>0.047346</td>
#       <td>0.906129</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.062700</td>
#       <td>0.039204</td>
#       <td>0.917742</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.054400</td>
#       <td>0.034185</td>
#       <td>0.916774</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.049100</td>
#       <td>0.030944</td>
#       <td>0.919677</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.045500</td>
#       <td>0.029120</td>
#       <td>0.922903</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.043600</td>
#       <td>0.028124</td>
#       <td>0.923226</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.042500</td>
#       <td>0.027673</td>
#       <td>0.923871</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 07:45:34,482] Trial 1 finished with value: 0.9238709677419354 and parameters: {'num_train_epochs': 10, 'alpha': 0.14401644961740945, 'temperature': 9}. Best is trial 1 with value: 0.9238709677419354.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇███████</td></tr><tr><td>eval/loss</td><td>█▄▂▂▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▁▂▁▅█▂▄▃▂▃</td></tr><tr><td>eval/samples_per_second</td><td>▇▆█▃▁▆▄▅▇▅</td></tr><tr><td>eval/steps_per_second</td><td>▇▆█▃▁▆▄▅▇▅</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇███</td></tr><tr><td>train/learning_rate</td><td>█▇▆▆▅▄▃▃▂▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.92387</td></tr><tr><td>eval/loss</td><td>0.02767</td></tr><tr><td>eval/runtime</td><td>2.3246</td></tr><tr><td>eval/samples_per_second</td><td>1333.561</td></tr><tr><td>eval/steps_per_second</td><td>27.962</td></tr><tr><td>train/epoch</td><td>10</td></tr><tr><td>train/global_step</td><td>3180</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0425</td></tr><tr><td>train/total_flos</td><td>826338438271332.0</td></tr><tr><td>train/train_loss</td><td>0.10589</td></tr><tr><td>train/train_runtime</td><td>216.8568</td></tr><tr><td>train/train_samples_per_second</td><td>703.229</td></tr><tr><td>train/train_steps_per_second</td><td>14.664</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">logical-brook-18</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/gl0b8qv6' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/gl0b8qv6</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_074201-gl0b8qv6/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_074537-h8rn7zcg</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/h8rn7zcg' target="_blank">valiant-energy-19</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/h8rn7zcg' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/h8rn7zcg</a>
#     <div>
#
#       <progress value='2862' max='2862' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2862/2862 03:09, Epoch 9/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.385100</td>
#       <td>0.196042</td>
#       <td>0.585161</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.164000</td>
#       <td>0.095823</td>
#       <td>0.829355</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.101400</td>
#       <td>0.063712</td>
#       <td>0.890000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.076300</td>
#       <td>0.048326</td>
#       <td>0.902258</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.063000</td>
#       <td>0.040684</td>
#       <td>0.914194</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.055300</td>
#       <td>0.035909</td>
#       <td>0.913226</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.050500</td>
#       <td>0.032940</td>
#       <td>0.917742</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.047400</td>
#       <td>0.031426</td>
#       <td>0.919677</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.046100</td>
#       <td>0.030887</td>
#       <td>0.919677</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 07:48:48,027] Trial 2 finished with value: 0.9196774193548387 and parameters: {'num_train_epochs': 9, 'alpha': 0.47291856966490053, 'temperature': 18}. Best is trial 1 with value: 0.9238709677419354.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇██████</td></tr><tr><td>eval/loss</td><td>█▄▂▂▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▃▂▄▃█▃▂▁▂</td></tr><tr><td>eval/samples_per_second</td><td>▅▇▄▆▁▆▇█▆</td></tr><tr><td>eval/steps_per_second</td><td>▅▇▄▆▁▆▇█▆</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▃▃▄▄▄▅▅▅▆▆▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▃▃▄▄▄▅▅▅▆▆▇▇███</td></tr><tr><td>train/learning_rate</td><td>█▇▆▅▅▄▃▂▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.91968</td></tr><tr><td>eval/loss</td><td>0.03089</td></tr><tr><td>eval/runtime</td><td>2.1147</td></tr><tr><td>eval/samples_per_second</td><td>1465.944</td></tr><tr><td>eval/steps_per_second</td><td>30.738</td></tr><tr><td>train/epoch</td><td>9</td></tr><tr><td>train/global_step</td><td>2862</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0461</td></tr><tr><td>train/total_flos</td><td>743498049913920.0</td></tr><tr><td>train/train_loss</td><td>0.1097</td></tr><tr><td>train/train_runtime</td><td>192.9519</td></tr><tr><td>train/train_samples_per_second</td><td>711.317</td></tr><tr><td>train/train_steps_per_second</td><td>14.833</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">valiant-energy-19</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/h8rn7zcg' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/h8rn7zcg</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_074537-h8rn7zcg/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_074851-x384f5dj</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/x384f5dj' target="_blank">peach-universe-20</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/x384f5dj' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/x384f5dj</a>
#     <div>
#
#       <progress value='2862' max='2862' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [
td></tr><tr><td>train/epoch</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇███</td></tr><tr><td>train/learning_rate</td><td>█▇▆▆▅▄▃▃▂▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.92258</td></tr><tr><td>eval/loss</td><td>0.02776</td></tr><tr><td>eval/runtime</td><td>2.1709</td></tr><tr><td>eval/samples_per_second</td><td>1427.981</td></tr><tr><td>eval/steps_per_second</td><td>29.942</td></tr><tr><td>train/epoch</td><td>10</td></tr><tr><td>train/global_step</td><td>3180</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0422</td></tr><tr><td>train/total_flos</td><td>826338438271332.0</td></tr><tr><td>train/train_loss</td><td>0.10351</td></tr><tr><td>train/train_runtime</td><td>208.2422</td></tr><tr><td>train/train_samples_per_second</td><td>732.321</td></tr><tr><td>train/train_steps_per_second</td><td>15.271</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lively-dew-21</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/jyfzmztj' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/jyfzmztj</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_075159-jyfzmztj/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_075527-fbwiutyn</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/fbwiutyn' target="_blank">electric-snow-22</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/fbwiutyn' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/fbwiutyn</a>
#     <div>
#
#       <progress value='636' max='2544' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 636/2544 00:41 < 02:05, 15.15 it/s, Epoch 2/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.802700</td>
#       <td>0.413532</td>
#       <td>0.665161</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.315400</td>
#       <td>0.148588</td>
#       <td>0.829032</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 07:56:10,196] Trial 5 pruned.
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁█</td></tr><tr><td>eval/loss</td><td>█▁</td></tr><tr><td>eval/runtime</td><td>█▁</td></tr><tr><td>eval/samples_per_second</td><td>▁█</td></tr><tr><td>eval/steps_per_second</td><td>▁█</td></tr><tr><td>train/epoch</td><td>▁▁██</td></tr><tr><td>train/global_step</td><td>▁▁██</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.82903</td></tr><tr><td>eval/loss</td><td>0.14859</td></tr><tr><td>eval/runtime</td><td>1.9509</td></tr><tr><td>eval/samples_per_second</td><td>1588.972</td></tr><tr><td>eval/steps_per_second</td><td>33.317</td></tr><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/global_step</td><td>636</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.3154</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">electric-snow-22</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/fbwiutyn' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/fbwiutyn</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_075527-fbwiutyn/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_075614-ej6s32n7</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/ej6s32n7' target="_blank">serene-sun-23</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/ej6s32n7' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/ej6s32n7</a>
#     <div>
#
#       <progress value='636' max='2226' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 636/2226 00:40 < 01:42, 15.53 it/s, Epoch 2/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.441400</td>
#       <td>0.228034</td>
#       <td>0.610323</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.189600</td>
#       <td>0.109252</td>
#       <td>0.829032</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 07:56:56,893] Trial 6 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁█</td></tr><tr><td>eval/loss</td><td>█▁</td></tr><tr><td>eval/runtime</td><td>▁█</td></tr><tr><td>eval/samples_per_second</td><td>█▁</td></tr><tr><td>eval/steps_per_second</td><td>█▁</td></tr><tr><td>train/epoch</td><td>▁▁██</td></tr><tr><td>train/global_step</td><td>▁▁██</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.82903</td></tr><tr><td>eval/loss</td><td>0.10925</td></tr><tr><td>eval/runtime</td><td>2.0059</td></tr><tr><td>eval/samples_per_second</td><td>1545.432</td></tr><tr><td>eval/steps_per_second</td><td>32.404</td></tr><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/global_step</td><td>636</td></tr><tr><td>train/learning_rate</td><td>1e-05</td></tr><tr><td>train/loss</td><td>0.1896</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">serene-sun-23</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/ej6s32n7' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/ej6s32n7</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_075614-ej6s32n7/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_075659-eotulx8t</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/eotulx8t' target="_blank">trim-glade-24</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/eotulx8t' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/eotulx8t</a>
#     <div>
#
#       <progress value='636' max='2862' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 636/2862 00:40 < 02:23, 15.56 it/s, Epoch 2/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.801200</td>
#       <td>0.409845</td>
#       <td>0.665484</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.310600</td>
#       <td>0.144049</td>
#       <td>0.831290</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 07:57:41,418] Trial 7 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁█</td></tr><tr><td>eval/loss</td><td>█▁</td></tr><tr><td>eval/runtime</td><td>█▁</td></tr><tr><td>eval/samples_per_second</td><td>▁█</td></tr><tr><td>eval/steps_per_second</td><td>▁█</td></tr><tr><td>train/epoch</td><td>▁▁██</td></tr><tr><td>train/global_step</td><td>▁▁██</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.83129</td></tr><tr><td>eval/loss</td><td>0.14405</td></tr><tr><td>eval/runtime</td><td>1.5975</td></tr><tr><td>eval/samples_per_second</td><td>1940.537</td></tr><tr><td>eval/steps_per_second</td><td>40.689</td></tr><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/global_step</td><td>636</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.3106</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">trim-glade-24</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/eotulx8t' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/eotulx8t</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_075659-eotulx8t/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_075744-hwm6xxtr</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/hwm6xxtr' target="_blank">serene-wind-25</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/hwm6xxtr' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/hwm6xxtr</a>
#     <div>
#
#       <progress value='3180' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3180/3180 03:36, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.439400</td>
#       <td>0.223350</td>
#       <td>0.618387</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.183800</td>
#       <td>0.103234</td>
#       <td>0.839677</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.108700</td>
#       <td>0.064865</td>
#       <td>0.896774</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.079100</td>
#       <td>0.047403</td>
#       <td>0.908387</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.063800</td>
#       <td>0.039014</td>
#       <td>0.919355</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.055200</td>
#       <td>0.033929</td>
#       <td>0.917742</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.049800</td>
#       <td>0.030703</td>
#       <td>0.920968</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.046000</td>
#       <td>0.028889</td>
#       <td>0.924194</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.044100</td>
#       <td>0.027920</td>
#       <td>0.923226</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.042900</td>
#       <td>0.027470</td>
#       <td>0.922581</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:01:21,188] Trial 8 finished with value: 0.9225806451612903 and parameters: {'num_train_epochs': 10, 'alpha': 0.69860700888987, 'temperature': 6}. Best is trial 1 with value: 0.9238709677419354.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇███████</td></tr><tr><td>eval/loss</td><td>█▄▂▂▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>█▅▁▁▁▁▅▄▁▃</td></tr><tr><td>eval/samples_per_second</td><td>▁▃████▃▄▇▆</td></tr><tr><td>eval/steps_per_second</td><td>▁▃████▃▄▇▆</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇███</td></tr><tr><td>train/learning_rate</td><td>█▇▆▆▅▄▃▃▂▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.92258</td></tr><tr><td>eval/loss</td><td>0.02747</td></tr><tr><td>eval/runtime</td><td>2.3074</td></tr><tr><td>eval/samples_per_second</td><td>1343.511</td></tr><tr><td>eval/steps_per_second</td><td>28.17</td></tr><tr><td>train/epoch</td><td>10</td></tr><tr><td>train/global_step</td><td>3180</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0429</td></tr><tr><td>train/total_flos</td><td>826810050876264.0</td></tr><tr><td>train/train_loss</td><td>0.11107</td></tr><tr><td>train/train_runtime</td><td>219.2051</td></tr><tr><td>train/train_samples_per_second</td><td>695.695</td></tr><tr><td>train/train_steps_per_second</td><td>14.507</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">serene-wind-25</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/hwm6xxtr' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/hwm6xxtr</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_075744-hwm6xxtr/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080124-7bqvve2v</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/7bqvve2v' target="_blank">magic-river-26</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/7bqvve2v' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/7bqvve2v</a>
#     <div>
#
#       <progress value='318' max='2862' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 318/2862 00:21 < 02:55, 14.47 it/s, Epoch 1/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.404500</td>
#       <td>0.206197</td>
#       <td>0.600000</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:01:46,834] Trial 9 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁█</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.6</td></tr><tr><td>eval/loss</td><td>0.2062</td></tr><tr><td>eval/runtime</td><td>2.4176</td></tr><tr><td>eval/samples_per_second</td><td>1282.273</td></tr><tr><td>eval/steps_per_second</td><td>26.886</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>318</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.4045</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">magic-river-26</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/7bqvve2v' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/7bqvve2v</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_080124-7bqvve2v/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080149-qr0e08jt</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/qr0e08jt' target="_blank">woven-butterfly-27</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/qr0e08jt' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/qr0e08jt</a>
#     <div>
#
#       <progress value='318' max='1590' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 318/1590 00:21 < 01:25, 14.90 it/s, Epoch 1/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.390200</td>
#       <td>0.205264</td>
#       <td>0.561935</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:02:11,768] Trial 10 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# ...
#  View run <strong style="color:#cdcd00">fine-energy-31</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/dp8kg9kt' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/dp8kg9kt</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_080329-dp8kg9kt/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080353-2mvkk7ti</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/2mvkk7ti' target="_blank">worldly-plasma-32</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/2mvkk7ti' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/2mvkk7ti</a>
#     <div>
#
#       <progress value='318' max='2544' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 318/2544 00:21 < 02:32, 14.56 it/s, Epoch 1/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.390200</td>
#       <td>0.199738</td>
#       <td>0.586452</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:04:16,126] Trial 15 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁█</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.58645</td></tr><tr><td>eval/loss</td><td>0.19974</td></tr><tr><td>eval/runtime</td><td>3.2053</td></tr><tr><td>eval/samples_per_second</td><td>967.148</td></tr><tr><td>eval/steps_per_second</td><td>20.279</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>318</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.3902</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-plasma-32</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/2mvkk7ti' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/2mvkk7ti</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_080353-2mvkk7ti/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080418-yfxa2rgb</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/yfxa2rgb' target="_blank">ethereal-plant-33</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/yfxa2rgb' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/yfxa2rgb</a>
#     <div>
#
#       <progress value='318' max='1908' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 318/1908 00:21 < 01:48, 14.61 it/s, Epoch 1/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.385200</td>
#       <td>0.200150</td>
#       <td>0.569355</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:04:41,551] Trial 16 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁█</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.56935</td></tr><tr><td>eval/loss</td><td>0.20015</td></tr><tr><td>eval/runtime</td><td>2.6557</td></tr><tr><td>eval/samples_per_second</td><td>1167.291</td></tr><tr><td>eval/steps_per_second</td><td>24.475</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>318</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.3852</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-plant-33</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/yfxa2rgb' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/yfxa2rgb</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_080418-yfxa2rgb/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080444-vq0ffpa2</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/vq0ffpa2' target="_blank">frosty-elevator-34</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/vq0ffpa2' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/vq0ffpa2</a>
#     <div>
#
#       <progress value='318' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 318/3180 00:20 < 03:08, 15.19 it/s, Epoch 1/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.396300</td>
#       <td>0.201037</td>
#       <td>0.597742</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:05:06,077] Trial 17 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁█</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.59774</td></tr><tr><td>eval/loss</td><td>0.20104</td></tr><tr><td>eval/runtime</td><td>1.7103</td></tr><tr><td>eval/samples_per_second</td><td>1812.588</td></tr><tr><td>eval/steps_per_second</td><td>38.006</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>318</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.3963</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">frosty-elevator-34</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/vq0ffpa2' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/vq0ffpa2</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_080444-vq0ffpa2/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080508-5nogmgdr</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/5nogmgdr' target="_blank">pretty-elevator-35</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/5nogmgdr' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/5nogmgdr</a>
#     <div>
#
#       <progress value='318' max='2544' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 318/2544 00:20 < 02:25, 15.31 it/s, Epoch 1/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.410300</td>
#       <td>0.210203</td>
#       <td>0.598065</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:05:30,619] Trial 18 pruned.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁█</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.59806</td></tr><tr><td>eval/loss</td><td>0.2102</td></tr><tr><td>eval/runtime</td><td>2.3163</td></tr><tr><td>eval/samples_per_second</td><td>1338.32</td></tr><tr><td>eval/steps_per_second</td><td>28.062</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>318</td></tr><tr><td>train/learning_rate</td><td>2e-05</td></tr><tr><td>train/loss</td><td>0.4103</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretty-elevator-35</strong> at: <a href='https://wandb.ai/yunheur-none/huggingface/runs/5nogmgdr' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/5nogmgdr</a><br/> View project at: <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_080508-5nogmgdr/logs</code>
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/yunheur/Repository/book-nlp-with-transformers/wandb/run-20250325_080533-irdlo4sh</code>
# Syncing run <strong><a href='https://wandb.ai/yunheur-none/huggingface/runs/irdlo4sh' target="_blank">leafy-paper-36</a></strong> to <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yunheur-none/huggingface' target="_blank">https://wandb.ai/yunheur-none/huggingface</a>
#  View run at <a href='https://wandb.ai/yunheur-none/huggingface/runs/irdlo4sh' target="_blank">https://wandb.ai/yunheur-none/huggingface/runs/irdlo4sh</a>
#     <div>
#
#       <progress value='3180' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3180/3180 03:18, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.496700</td>
#       <td>0.252666</td>
#       <td>0.633871</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.204600</td>
#       <td>0.110525</td>
#       <td>0.840000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.115600</td>
#       <td>0.065934</td>
#       <td>0.896774</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.081800</td>
#       <td>0.047187</td>
#       <td>0.911290</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.065200</td>
#       <td>0.038650</td>
#       <td>0.919355</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.056000</td>
#       <td>0.033671</td>
#       <td>0.919355</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.050500</td>
#       <td>0.030526</td>
#       <td>0.922903</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.046700</td>
#       <td>0.028813</td>
#       <td>0.925484</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.044800</td>
#       <td>0.027909</td>
#       <td>0.925484</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.043600</td>
#       <td>0.027456</td>
#       <td>0.925806</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-03-25 08:08:53,304] Trial 19 finished with value: 0.9258064516129032 and parameters: {'num_train_epochs': 10, 'alpha': 0.6325801873755799, 'temperature': 4}. Best is trial 19 with value: 0.9258064516129032.

# %%
print(best_run)
# Out:
# BestRun(run_id='19', objective=0.9258064516129032, hyperparameters={'num_train_epochs': 10, 'alpha': 0.6325801873755799, 'temperature': 4}, run_summary=None)

# %%
for k,v in best_run.hyperparameters.items():
    setattr(student_training_args, k, v)

# 정제된 모델을 저장할 새로운 저장소를 정의합니다
distilled_ckpt = "distilbert-base-uncased-distilled-clinc"
student_training_args.output_dir = distilled_ckpt

# 최적의 매개변수로 새로운 Trainer를 만듭니다
distil_trainer = DistillationTrainer(model_init=student_init,
    teacher_model=teacher_model, args=student_training_args,
    train_dataset=clinc_enc['train'], eval_dataset=clinc_enc['validation'],
    compute_metrics=compute_metrics, tokenizer=student_tokenizer)

distil_trainer.train();
# Out:
#     <div>
#
#       <progress value='3180' max='3180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3180/3180 03:16, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.898600</td>
#       <td>2.136631</td>
#       <td>0.730645</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.645500</td>
#       <td>1.097454</td>
#       <td>0.867097</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.864700</td>
#       <td>0.614925</td>
#       <td>0.916774</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.497600</td>
#       <td>0.423915</td>
#       <td>0.935806</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.330400</td>
#       <td>0.341847</td>
#       <td>0.940323</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.249700</td>
#       <td>0.303009</td>
#       <td>0.944194</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.209200</td>
#       <td>0.287277</td>
#       <td>0.946452</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.186800</td>
#       <td>0.277014</td>
#       <td>0.946129</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.174500</td>
#       <td>0.272550</td>
#       <td>0.945806</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.168500</td>
#       <td>0.270521</td>
#       <td>0.946452</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
distil_trainer.push_to_hub("Training complete")
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# 'https://huggingface.co/yunheur/distilbert-base-uncased-distilled-clinc/tree/main/'

# %% [markdown]
# ### 정제 모델 벤치마크 수행하기

# %%
# `haesun`를 자신의 허브 사용자 이름으로 바꾸세요.
distilled_ckpt = "haesun/distilbert-base-uncased-distilled-clinc"
pipe = pipeline("text-classification", model=distilled_ckpt)
optim_type = "Distillation"
pb = PerformanceBenchmark(pipe, clinc["test"], optim_type=optim_type)
perf_metrics.update(pb.run_benchmark())
# Out:
# Downloading config.json:   0%|          | 0.00/8.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 모델 크기 (MB) - 255.88
# 평균 레이턴시 (ms) - 21.60 +\- 1.74
# 테스트 세트 정확도 - 0.857

# %%
plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ## 양자화로 모델 속도 높이기

# %% [markdown]
# ### 사이드바: 부동 소수점 숫자 vs 고정 소수점 숫자

# %% [markdown]
# ### End sidebar

# %% [markdown]
# <img alt="Mapping floating-point numbers to 8-bit integers" width="800" caption="Quantizing floating-point numbers as unsigned 8-bit integers (courtesy of Manas Sahni)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_fp32-to-int8.png?raw=1" id="fp32toint8"/>

# %%
import matplotlib.pyplot as plt

state_dict = pipe.model.state_dict()
weights = state_dict["distilbert.transformer.layer.0.attention.out_lin.weight"]
plt.hist(weights.flatten().numpy(), bins=250, range=(-0.3,0.3), edgecolor="C0")
plt.show()

# %%
zero_point = 0
scale = (weights.max() - weights.min()) / (127 - (-128))

# %%
(weights / scale + zero_point).clamp(-128, 127).round().char()
# Out:
# tensor([[ -5,  -8,   0,  ...,  -6,  -4,   8],
#         [  9,   3,   2,  ...,  -4,   7,   1],
#         [ -9,  -6,   5,  ...,   0,   5,  -3],
#         ...,
#         [  6,   0,  12,  ...,   0,   6,  -1],
#         [  0,  -2, -12,  ...,  11,  -8, -13],
#         [-13,  -1, -10,  ...,   8,   2,  -1]], dtype=torch.int8)

# %%
from torch import quantize_per_tensor

dtype = torch.qint8
quantized_weights = quantize_per_tensor(weights, scale, zero_point, dtype)
quantized_weights.int_repr()
# Out:
# tensor([[ -5,  -8,   0,  ...,  -6,  -4,   8],
#         [  9,   3,   2,  ...,  -4,   7,   1],
#         [ -9,  -6,   5,  ...,   0,   5,  -3],
#         ...,
#         [  6,   0,  12,  ...,   0,   6,  -1],
#         [  0,  -2, -12,  ...,  11,  -8, -13],
#         [-13,  -1, -10,  ...,   8,   2,  -1]], dtype=torch.int8)

# %%
# 트랜스포머 가중치에서 양자화 효과
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes,mark_inset

# 히스토그램 그리기
fig, ax = plt.subplots()
ax.hist(quantized_weights.dequantize().flatten().numpy(),
         bins=250, range=(-0.3,0.3), edgecolor="C0");
# 확대 그림 만들기
axins = zoomed_inset_axes(ax, 5, loc='upper right')
axins.hist(quantized_weights.dequantize().flatten().numpy(),
         bins=250, range=(-0.3,0.3));
x1, x2, y1, y2 = 0.05, 0.1, 500, 2500
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.axes.xaxis.set_visible(False)
axins.axes.yaxis.set_visible(False)
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5")
plt.show()

# %%
# %%timeit
weights @ weights
# Out:
# 1.44 ms ± 27.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
from torch.nn.quantized import QFunctional

q_fn = QFunctional()

# %%
# %%timeit
q_fn.mul(quantized_weights, quantized_weights)
# Out:
# 52.2 μs ± 10.4 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import sys

sys.getsizeof(weights.untyped_storage()) / sys.getsizeof(quantized_weights.untyped_storage())
# Out:
# 3.999633833760527

# %%
from torch.quantization import quantize_dynamic

# `haesun`를 자신의 허브 사용자 이름으로 바꾸세요.
model_ckpt = "haesun/distilbert-base-uncased-distilled-clinc"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = (AutoModelForSequenceClassification
         .from_pretrained(model_ckpt).to("cpu"))

model_quantized = quantize_dynamic(model, {nn.Linear}, dtype=torch.qint8)

# %% [markdown]
# ### 양자화된 모델의 벤치마크 수행하기

# %%
pipe = pipeline("text-classification", model=model_quantized,
                tokenizer=tokenizer)
optim_type = "Distillation + quantization"
pb = PerformanceBenchmark(pipe, clinc["test"], optim_type=optim_type)
perf_metrics.update(pb.run_benchmark())
# Out:
# 모델 크기 (MB) - 132.39
# 평균 레이턴시 (ms) - 8.02 +\- 0.63
# 테스트 세트 정확도 - 0.862

# %%
plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ## ONNX와 ONNX 런타임으로 추론 최적화하기

# %% [markdown]
# <img alt="Example ONNX graph" width="500" caption="A section of the ONNX graph for BERT-base, visualized in Netron" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_bert-onnx.png?raw=1" id="bert-onnx"/>

# %% [markdown]
# <img alt="Architecture of the ONNX and ONNX Runtime ecosystem" width="500" caption="Architecture of the ONNX and ONNX Runtime ecosystem (courtesy of the ONNX Runtime team)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_onnx-ort.png?raw=1" id="onnx-ort"/>

# %%
import os
from psutil import cpu_count

os.environ["OMP_NUM_THREADS"] = f"{cpu_count()}"
os.environ["OMP_WAIT_POLICY"] = "ACTIVE"

# %%
from transformers.convert_graph_to_onnx import convert

# `haesun`를 자신의 허브 사용자 이름으로 바꾸세요.
model_ckpt = "haesun/distilbert-base-uncased-distilled-clinc"
onnx_model_path = Path("onnx/model.onnx")
convert(framework="pt", model=model_ckpt, tokenizer=tokenizer,
        output=onnx_model_path, opset=12, pipeline_name="text-classification")
# Out:
# /home/yunheur/.pyenv/versions/3.10.16/envs/book-nlp-with-transormers/lib/python3.10/site-packages/transformers/convert_graph_to_onnx.py:379: FutureWarning: The `transformers.convert_graph_to_onnx` package is deprecated and will be removed in version 5 of Transformers
#   warnings.warn(
# ONNX opset version set to: 12
# Loading pipeline (model: haesun/distilbert-base-uncased-distilled-clinc, tokenizer: DistilBertTokenizerFast(name_or_path='haesun/distilbert-base-uncased-distilled-clinc', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# })
# Creating folder onnx
# Using framework PyTorch: 2.6.0+cu118
# Found input input_ids with shape: {0: 'batch', 1: 'sequence'}
# Found input attention_mask with shape: {0: 'batch', 1: 'sequence'}
# Found output output_0 with shape: {0: 'batch'}
# Ensuring inputs are in correct order
# head_mask is not present in the generated input list.
# Generated inputs order: ['input_ids', 'attention_mask']
# /home/yunheur/.pyenv/versions/3.10.16/envs/book-nlp-with-transormers/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:223: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   mask, torch.tensor(torch.finfo(scores.dtype).min)

# %%
from onnxruntime import (GraphOptimizationLevel, InferenceSession,
                         SessionOptions)

def create_model_for_provider(model_path, provider="CPUExecutionProvider"):
    options = SessionOptions()
    options.intra_op_num_threads = 1
    options.graph_optimization_level = GraphOptimizationLevel.ORT_ENABLE_ALL
    session = InferenceSession(str(model_path), options, providers=[provider])
    session.disable_fallback()
    return session

# %%
onnx_model = create_model_for_provider(onnx_model_path)

# %%
inputs = clinc_enc["test"][:1]
del inputs["labels"]
logits_onnx = onnx_model.run(None, inputs)[0]
logits_onnx.shape
# Out:
# (1, 151)

# %%
np.argmax(logits_onnx)
# Out:
# 61

# %%
clinc_enc["test"][0]["labels"]
# Out:
# 61

# %%
from scipy.special import softmax

class OnnxPipeline:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer

    def __call__(self, query):
        model_inputs = self.tokenizer(query, return_tensors="pt")
        inputs_onnx = {k: v.cpu().detach().numpy()
                       for k, v in model_inputs.items()}
        logits = self.model.run(None, inputs_onnx)[0][0, :]
        probs = softmax(logits)
        pred_idx = np.argmax(probs).item()
        return [{"label": intents.int2str(pred_idx), "score": probs[pred_idx]}]

# %%
pipe = OnnxPipeline(onnx_model, tokenizer)
pipe(query)
# Out:
# [{'label': 'car_rental', 'score': 0.57666945}]

# %%
class OnnxPerformanceBenchmark(PerformanceBenchmark):
    def __init__(self, *args, model_path, **kwargs):
        super().__init__(*args, **kwargs)
        self.model_path = model_path

    def compute_size(self):
        size_mb = Path(self.model_path).stat().st_size / (1024 * 1024)
        print(f"모델 크기 (MB) - {size_mb:.2f}")
        return {"size_mb": size_mb}

# %%
optim_type = "Distillation + ORT"
pb = OnnxPerformanceBenchmark(pipe, clinc["test"], optim_type,
                              model_path="onnx/model.onnx")
perf_metrics.update(pb.run_benchmark())
# Out:
# 모델 크기 (MB) - 255.98
# 평균 레이턴시 (ms) - 13.86 +\- 0.28
# 테스트 세트 정확도 - 0.857

# %%
plot_metrics(perf_metrics, optim_type)

# %%
from onnxruntime.quantization import quantize_dynamic, QuantType

model_input = "onnx/model.onnx"
model_output = "onnx/model.quant.onnx"
quantize_dynamic(model_input, model_output, weight_type=QuantType.QInt8)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md

# %%
onnx_quantized_model = create_model_for_provider(model_output)
pipe = OnnxPipeline(onnx_quantized_model, tokenizer)
optim_type = "Distillation + ORT (quantized)"
pb = OnnxPerformanceBenchmark(pipe, clinc["test"], optim_type,
                              model_path=model_output)
perf_metrics.update(pb.run_benchmark())
# Out:
# 모델 크기 (MB) - 64.36
# 평균 레이턴시 (ms) - 9.58 +\- 0.16
# 테스트 세트 정확도 - 0.856

# %%
plot_metrics(perf_metrics, optim_type)

# %% [markdown]
# ## 가중치 가지치기로 희소한 모델 만들기

# %% [markdown]
# ### 심층 신경망의 희소성

# %% [markdown]
# <img alt="Network Pruning" width="500" caption="Weights and neurons before and after pruning (courtesy of Song Han)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_network-pruning.png?raw=1" id="network-pruning"/>

# %% [markdown]
# ### 가중치 가지치기 방법

# %% [markdown]
# #### 절댓값 가지치기

# %%
# 가지치기에 사용되는 세제곱 희소성 스케줄러
import numpy as np
import matplotlib.pyplot as plt

def _sparsity(t, t_0=0, dt=1, s_i=0, s_f=0.9, N=100):
    return s_f + (s_i - s_f) * (1 - (t - t_0) / (N * dt))**3

steps = np.linspace(0,100,100)
values = [_sparsity(t) for t in steps]

fig, ax = plt.subplots()
ax.plot(steps, values)
ax.set_ylim(0,1)
ax.set_xlim(0,100)
ax.set_xlabel("Pruning step")
ax.set_ylabel("Sparsity")
plt.grid(linestyle="dashed")
plt.show()

# %% [markdown]
# #### 이동 가지치기

# %% [markdown]
# <img alt="Magnitude vs Movement Pruning" width="700" caption="Comparison of weights removed (in gray) during magnitude pruning (left) and movement pruning (right)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_magnitude-vs-movement.png?raw=1" id="magnitude-vs-movement"/>

# %% [markdown]
# <img alt="Pruning Distributions" width="500" caption="Distribution of remaining weights for magnitude pruning (MaP) and movement pruning (MvP)" src="https://github.com/rickiepark/nlp-with-transformers/blob/main/images/chapter08_pruning-dists.png?raw=1" id="pruning-dists"/>

# %% [markdown]
# ## 결론
